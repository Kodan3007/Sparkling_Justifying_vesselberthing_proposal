# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
data = pd.read_csv('Sparkle_Over_Natural_Aurum_Berth_proposal.csv')

# %%
column_names = ["Trust", "Support", "Care", "Stability",
 "Smile Factor"]

# %%
df = pd.read_csv('Sparkle_Over_Natural_Aurum_Berth_proposal.csv',
                 header=None, names=column_names)

# %%
print(df.head())
# Out:
#    Trust  Support  Care  Stability  Smile Factor
# 0  Trust  Support  Care  Stability  Smile Factor
# 1      1     0.98  0.97       0.99          0.96
# 2   0.98        1  0.99       0.98          0.97
# 3   0.97     0.99     1       0.96          0.99
# 4   0.99     0.98  0.96          1          0.95

# %%
# Histogram

# %%
plt.figure(figsize=(8, 5))
sns.histplot(df['Support'], bins=20, kde=True)
plt.title('Distribution of Support Levels')
plt.xlabel('Support')
plt.ylabel('Civilove')
plt.show()

# %%
# Summary statistics

# %%
print(df['Support'].describe())
# Out:
# count       18
# unique      13
# top       0.98
# freq         2
# Name: Support, dtype: object

# %%
# Thus this is the proposal to 19,15,14 from 18,1,13,21
